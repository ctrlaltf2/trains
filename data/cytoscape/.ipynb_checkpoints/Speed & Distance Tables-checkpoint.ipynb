# %% [markdown]
# # Green Line

# %%
import pandas as pd

green_line_info = pd.read_csv('./TrackLayoutGreen.csv')
green_line_info

g_track_info = {}

# %%
import json
from sympy import Rational, N

green_track_info = {}

for index, block in green_line_info.iterrows():
    block_id = block['Block ID']
    green_track_info[block_id] = {
        'length': float(block['Length']), # m
        'grade': float(block['Grade']),  # %
        'speed_limit': float(block['Speed Limit']), # km/hr
        'elevation': float(block['Elevation']), # ?
        'traverse_time': float(N( float(block['Length']) / (float(block['Speed Limit']) * Rational(5, 18)))), # s
    }
    
g_track_info['green'] = green_track_info

# %% [markdown]
# # Red Line

# %%
import pandas as pd

red_line_info = pd.read_csv('./TrackLayoutRed.csv')
red_line_info
# Out:
#    Line Section  Block ID  Length  Grade  Speed Limit Infrastructure  \
# 0   Red       A         1    50.0    0.5           40            NaN
# 1   Red       A         2    50.0    1.0           40            NaN
# 2   Red       A         3    50.0    1.5           40            NaN
# 3   Red       B         4    50.0    2.0           40            NaN
# 4   Red       B         5    50.0    1.5           40            NaN
# ..  ...     ...       ...     ...    ...          ...            ...
# 71  Red       R        72    50.0    0.0           55    UNDERGROUND
# 72  Red       S        73    50.0    0.0           55    UNDERGROUND
# 73  Red       S        74    50.0    0.0           55    UNDERGROUND
# 74  Red       S        75    50.0    0.0           55    UNDERGROUND
# 75  Red       T        76    50.0    0.0           55    UNDERGROUND
#
#    Station Side  Elevation  Cumulative Elevation
# 0           NaN       0.25                  0.25
# 1           NaN       0.50                  0.75
# 2           NaN       0.75                  1.50
# 3           NaN       1.00                  2.50
# 4           NaN       0.75                  3.25
# ..          ...        ...                   ...
# 71          NaN       0.00                 -1.24
# 72          NaN       0.00                 -1.24
# 73          NaN       0.00                 -1.24
# 74          NaN       0.00                 -1.24
# 75          NaN       0.00                 -1.24
#
# [76 rows x 10 columns]

# %%
import json
from sympy import Rational, N

red_track_info = {}

for index, block in red_line_info.iterrows():
    block_id = block['Block ID']
    red_track_info[block_id] = {
        'length': float(block['Length']), # m
        'grade': float(block['Grade']),  # %
        'speed_limit': float(block['Speed Limit']), # km/hr
        'elevation': float(block['Elevation']), # ?
        'traverse_time': float(N( float(block['Length']) / (float(block['Speed Limit']) * Rational(5, 18)))), # s
    }
    
g_track_info['red'] = red_track_info

def update_table(line, new_table):
    with open('../TrackModel-info.json', 'r') as input:
        current_table = json.load(input)

    current_table[line] = new_table

    with open('../TrackModel-info.json', 'w') as output:
        json.dump(new_table, output)
# Out:
# {1: {'length': 50.0,
#   'grade': 0.5,
#   'speed_limit': 40.0,
#   'elevation': 0.25,
#   'traverse_time': 4.5},
#  2: {'length': 50.0,
#   'grade': 1.0,
#   'speed_limit': 40.0,
#   'elevation': 0.5,
#   'traverse_time': 4.5},
#  3: {'length': 50.0,
#   'grade': 1.5,
#   'speed_limit': 40.0,
#   'elevation': 0.75,
#   'traverse_time': 4.5},
#  4: {'length': 50.0,
#   'grade': 2.0,
#   'speed_limit': 40.0,
#   'elevation': 1.0,
#   'traverse_time': 4.5},
#  5: {'length': 50.0,
#   'grade': 1.5,
#   'speed_limit': 40.0,
#   'elevation': 0.75,
#   'traverse_time': 4.5},
#  6: {'length': 50.0,
#   'grade': 1.0,
#   'speed_limit': 40.0,
#   'elevation': 0.5,
#   'traverse_time': 4.5},
#  7: {'length': 75.0,
#   'grade': 0.5,
#   'speed_limit': 40.0,
#   'elevation': 0.38,
#   'traverse_time': 6.75},
#  8: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 40.0,
#   'elevation': 0.0,
#   'traverse_time': 6.75},
#  9: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 40.0,
#   'elevation': 0.0,
#   'traverse_time': 6.75},
#  10: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 40.0,
#   'elevation': 0.0,
#   'traverse_time': 6.75},
#  11: {'length': 75.0,
#   'grade': -0.5,
#   'speed_limit': 40.0,
#   'elevation': -0.38,
#   'traverse_time': 6.75},
#  12: {'length': 75.0,
#   'grade': -1.0,
#   'speed_limit': 40.0,
#   'elevation': -0.75,
#   'traverse_time': 6.75},
#  13: {'length': 70.0,
#   'grade': -2.0,
#   'speed_limit': 40.0,
#   'elevation': -1.4,
#   'traverse_time': 6.3},
#  14: {'length': 60.0,
#   'grade': -1.25,
#   'speed_limit': 40.0,
#   'elevation': -0.75,
#   'traverse_time': 5.3999999999999995},
#  15: {'length': 60.0,
#   'grade': -1.0,
#   'speed_limit': 40.0,
#   'elevation': -0.6,
#   'traverse_time': 5.3999999999999995},
#  16: {'length': 50.0,
#   'grade': -0.5,
#   'speed_limit': 40.0,
#   'elevation': -0.25,
#   'traverse_time': 4.5},
#  17: {'length': 200.0,
#   'grade': -0.5,
#   'speed_limit': 55.0,
#   'elevation': -1.0,
#   'traverse_time': 13.09090909090909},
#  18: {'length': 400.0,
#   'grade': -0.06025,
#   'speed_limit': 70.0,
#   'elevation': -0.24,
#   'traverse_time': 20.57142857142857},
#  19: {'length': 400.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 20.57142857142857},
#  20: {'length': 200.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 10.285714285714285},
#  21: {'length': 100.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 6.545454545454545},
#  22: {'length': 100.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 6.545454545454545},
#  23: {'length': 100.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 6.545454545454545},
#  24: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  25: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  26: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  27: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  28: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  29: {'length': 60.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0857142857142854},
#  30: {'length': 60.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0857142857142854},
#  31: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  32: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  33: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  34: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  35: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  36: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  37: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  38: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  39: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  40: {'length': 60.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0857142857142854},
#  41: {'length': 60.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0857142857142854},
#  42: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  43: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  44: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  45: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 2.571428571428571},
#  46: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.8571428571428568},
#  47: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.8571428571428568},
#  48: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 70.0,
#   'elevation': 0.0,
#   'traverse_time': 3.8571428571428568},
#  49: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 60.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0},
#  50: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 60.0,
#   'elevation': 0.0,
#   'traverse_time': 3.0},
#  51: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  52: {'length': 43.2,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 2.8276363636363633},
#  53: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  54: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  55: {'length': 75.0,
#   'grade': 0.5,
#   'speed_limit': 55.0,
#   'elevation': 0.38,
#   'traverse_time': 4.909090909090908},
#  56: {'length': 75.0,
#   'grade': 0.5,
#   'speed_limit': 55.0,
#   'elevation': 0.38,
#   'traverse_time': 4.909090909090908},
#  57: {'length': 75.0,
#   'grade': 0.5,
#   'speed_limit': 55.0,
#   'elevation': 0.38,
#   'traverse_time': 4.909090909090908},
#  58: {'length': 75.0,
#   'grade': 1.0,
#   'speed_limit': 55.0,
#   'elevation': 0.75,
#   'traverse_time': 4.909090909090908},
#  59: {'length': 75.0,
#   'grade': 0.5,
#   'speed_limit': 55.0,
#   'elevation': 0.38,
#   'traverse_time': 4.909090909090908},
#  60: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 4.909090909090908},
#  61: {'length': 75.0,
#   'grade': -0.5,
#   'speed_limit': 55.0,
#   'elevation': -0.38,
#   'traverse_time': 4.909090909090908},
#  62: {'length': 75.0,
#   'grade': -1.0,
#   'speed_limit': 55.0,
#   'elevation': -0.75,
#   'traverse_time': 4.909090909090908},
#  63: {'length': 75.0,
#   'grade': -1.0,
#   'speed_limit': 55.0,
#   'elevation': -0.75,
#   'traverse_time': 4.909090909090908},
#  64: {'length': 75.0,
#   'grade': -0.5,
#   'speed_limit': 55.0,
#   'elevation': -0.38,
#   'traverse_time': 4.909090909090908},
#  65: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 4.909090909090908},
#  66: {'length': 75.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 4.909090909090908},
#  67: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  68: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  69: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  70: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  71: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  72: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  73: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  74: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  75: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725},
#  76: {'length': 50.0,
#   'grade': 0.0,
#   'speed_limit': 55.0,
#   'elevation': 0.0,
#   'traverse_time': 3.2727272727272725}}
